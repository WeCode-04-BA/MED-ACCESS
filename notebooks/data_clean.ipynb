# %% [markdown]
# # Cleaning medical datasets
# * clean diseases and symptoms dataset
# * look at symptoms description,precation, and severity datasets
# * Make sure every dataset set is cleaned and prepared

# %% [markdown]
# ## Diseases and symptoms

# %%
import pandas as pd
diseases = pd.read_csv("../data/raw/dataset.csv")

# %%
#view first 10 rows 
diseases[:10]
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 5  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 6  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 7  Fungal infection     itching              skin_rash    dischromic _patches
# 8  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 9  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# ...

# %% [markdown]
# ## The data is very messy
# * TO DO:
#   1. Strip spaces and lowercase
#   2. Remove duplicates
#   3. Drop empty symptoms columns

# %%
#Strip space and lowercase,replace spaces
for col in diseases.columns:
    diseases[col] = diseases[col].astype(str).str.strip().str.lower().str.replace(r"[\s_]+" , "_",regex =True)
    diseases[col] = diseases[col].replace("nan",pd.NA)
    
#view first 10 rows
diseases[:10]
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  fungal_infection    itching             skin_rash  nodal_skin_eruptions
# 1  fungal_infection  skin_rash  nodal_skin_eruptions    dischromic_patches
# 2  fungal_infection    itching  nodal_skin_eruptions    dischromic_patches
# 3  fungal_infection    itching             skin_rash    dischromic_patches
# 4  fungal_infection    itching             skin_rash  nodal_skin_eruptions
# 5  fungal_infection  skin_rash  nodal_skin_eruptions    dischromic_patches
# 6  fungal_infection    itching  nodal_skin_eruptions    dischromic_patches
# 7  fungal_infection    itching             skin_rash    dischromic_patches
# 8  fungal_infection    itching             skin_rash  nodal_skin_eruptions
# 9  fungal_infection    itching             skin_rash  nodal_skin_eruptions
#
#             Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# ...

# %% [markdown]
# ## Now the data is more readable
# * remove duplicates

# %%
diseases = diseases.drop_duplicates()
diseases[:10]
# Out:
#              Disease            Symptom_1             Symptom_2  \
# 0   fungal_infection              itching             skin_rash
# 1   fungal_infection            skin_rash  nodal_skin_eruptions
# 2   fungal_infection              itching  nodal_skin_eruptions
# 3   fungal_infection              itching             skin_rash
# 4   fungal_infection              itching             skin_rash
# 10           allergy  continuous_sneezing             shivering
# 11           allergy            shivering                chills
# 12           allergy  continuous_sneezing                chills
# 13           allergy  continuous_sneezing             shivering
# 14           allergy  continuous_sneezing             shivering
#
#                Symptom_3           Symptom_4 Symptom_5 Symptom_6 Symptom_7  \
# 0   nodal_skin_eruptions  dischromic_patches      <NA>      <NA>      <NA>
# 1     dischromic_patches                <NA>      <NA>      <NA>      <NA>
# ...

# %% [markdown]
# ## So far so good, removed duplicates
# * Now we will drop  empty symptom columns
# * We will  try to drop columns with 80% missing values

# %%
threshold = len(diseases) * 0.2
diseases = diseases.dropna(axis=1, thresh= threshold)

#view first 15 rows
diseases[:15]
# Out:
#              Disease            Symptom_1             Symptom_2  \
# 0   fungal_infection              itching             skin_rash
# 1   fungal_infection            skin_rash  nodal_skin_eruptions
# 2   fungal_infection              itching  nodal_skin_eruptions
# 3   fungal_infection              itching             skin_rash
# 4   fungal_infection              itching             skin_rash
# 10           allergy  continuous_sneezing             shivering
# 11           allergy            shivering                chills
# 12           allergy  continuous_sneezing                chills
# 13           allergy  continuous_sneezing             shivering
# 14           allergy  continuous_sneezing             shivering
# 20              gerd         stomach_pain               acidity
# 21              gerd         stomach_pain      ulcers_on_tongue
# 22              gerd         stomach_pain               acidity
# 23              gerd         stomach_pain               acidity
# ...

# %% [markdown]
# ## Done with diseases and symptoms dataset
# * Export the dataset

# %%
diseases.to_csv("../data/processed/dataset_cleaned.csv", index=False)
